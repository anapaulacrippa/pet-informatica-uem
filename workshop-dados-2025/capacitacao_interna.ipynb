# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
caminho = '/content/drive/MyDrive/PET-Informática/Capacitação Interna - Ciência de Dados/dados_exercicio.csv'
df = pd.read_csv(caminho)

# %%
print("Visualização das 7 primeiras linhas")
display(df.head(7))

print("\n\nVisualização das 3 últimas linhas")
display(df.tail(3))
# Out:
# Visualização das 7 primeiras linhas
#                                       Nome       Plataforma  Ano_Lancamento  \
# 0  The Legend of Zelda: Breath of the Wild  Nintendo Switch          2017.0
# 1                      Super Mario Odyssey  Nintendo Switch          2017.0
# 2                    Red Dead Redemption 2    PlayStation 4          2018.0
# 3                       Grand Theft Auto V    PlayStation 4          2014.0
# 4                           Cyberpunk 2077               PC          2020.0
# 5                 The Witcher 3: Wild Hunt               PC          2015.0
# 6                                Minecraft               PC          2011.0
#
#              Genero  Vendas_Global_Milhoes  Nota_Critica  Nota_Usuario
# 0  Action-Adventure                  29.81          97.0           8.7
# 1        Platformer                  25.12          97.0           8.9
# 2  Action-Adventure                  23.11          97.0           8.7
# ...

# %%
print("Quantidade de linhas:", df.shape[0])
print("\nQuantidade de colunas:", df.shape[1])
print("\nInformações do DataFrame:\n")
df.info()
# Out:
# Quantidade de linhas: 54
#
# Quantidade de colunas: 7
#
# Informações do DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome                   54 non-null     object
#  1   Plataforma             54 non-null     object
#  2   Ano_Lancamento         53 non-null     float64
#  3   Genero                 54 non-null     object
#  4   Vendas_Global_Milhoes  44 non-null     float64
#  5   Nota_Critica           53 non-null     float64
#  6   Nota_Usuario           54 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 3.1+ KB

# %%
print("Resumo estatístico:\n", df.describe())
# Out:
# Resumo estatístico:
#         Ano_Lancamento  Vendas_Global_Milhoes  Nota_Critica  Nota_Usuario
# count       53.000000              44.000000     53.000000     54.000000
# mean      2011.981132              10.393864     89.358491      8.172222
# std          8.802296               9.860732      6.495840      1.324574
# min       1992.000000               1.000000     69.000000      4.100000
# 25%       2005.000000               2.350000     86.000000      7.725000
# 50%       2015.000000               6.500000     91.000000      8.800000
# 75%       2018.000000              15.175000     94.000000      9.000000
# max       2022.000000              42.210000     97.000000      9.300000
